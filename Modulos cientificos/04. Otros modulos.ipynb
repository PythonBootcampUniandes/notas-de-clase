# %% [markdown]
# # Sympy: Matemática simbólica

# %%
from sympy import init_session
init_session()

# %% [markdown]
# ## Algebra

# %%
(x + x) * x

# %%
solve( x**2 + 2*x - 8, x)

# %%
a, b, c, d = symbols('a b c d')
solve( a*x**2 + b*x + c, x)

# %%
together(a/b + c/d)

# %%
apart( (x**2+x+4)/(x+2) )

# %%
p = (x + y)**2
p

# %%
p_exp = expand(p)
p_exp

# %%
factor(p_exp)

# %% [markdown]
# ## Trigonometría

# %%
sin(x) == cos(x - pi/2)

# %%
expand(sin(2*x))

# %%
expand_trig(sin(2*x))

# %%
simplify( sin(x)*cos(y) + cos(x)*sin(y) )

# %% [markdown]
# ## Cálculo

# %%
limit( (1+1/n)**n, n, oo)

# %%
diff( x**3, x )

# %%
diff( x**2 * sin(x), x )

# %%
integrate(sin(x))

# %%
integrate(log(x))

# %%
integrate(sin(x**2), (x, -oo, oo))

# %%
y = symbols('y')
integrate(exp(-x**2 - y**2), (x, -oo, oo), (y, -oo, oo))

# %%
y = Function('y')
dsolve(Eq(y(t).diff(t, t) - y(t), exp(t)), y(t))

# %% [markdown]
# # Networkx: Grafos

# %%
# %reset

# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_edges_from([(1,2), (1,3)])
G.add_nodes_from([4, 5, 6])
G.add_edge(4, 6)

# %%
# %matplotlib inline
nx.draw(G)

# %%
list(nx.connected_components(G))

# %%
nx.degree(G)

# %% [markdown]
# # Más módulos

# %% [markdown]
# * **scikit-learn**: Para hacer machine learning
# * **cvxopt**: Para resolver problemas de optimización
# * **scikit-image**: Para hacer análisis de imágenes
# * **geopandas**: Para trabahar con datos geográficos en DataFrames
# * **xray**: Para trabajar con arreglos multidimensionales con etiquetas
# * **seaborn**: Para hacer gráficos estadísticos
